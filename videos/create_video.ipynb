# %%
import cv2
import numpy as np
import os
 
from os.path import isfile, join
 
def convert_frames_to_video(pathIn,pathOut,fps):
    frame_array = []
    files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]
 
    #for sorting the file names properly
    files.sort() #key = lambda x: int(x[5:-4]))
 
    for i in range(len(files)):
        filename=pathIn + files[i]
        #reading each files
        img = cv2.imread(filename)
        height, width, layers = img.shape
        size = (width,height)
        print(filename)
        #inserting the frames into an image array
        frame_array.append(img)
 
    out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
 
    for i in range(len(frame_array)):
        # writing to a image array
        
        cv2.putText(frame_array[i],files[i],(20,30), cv2.FONT_HERSHEY_SIMPLEX, 0.8,(255,0,255),2) 
        out.write(frame_array[i])
    out.release()
 
def main():
    pathIn= './nst_wall/'
    pathOut = 'nst_wallvid.avi'
    fps = 10
    convert_frames_to_video(pathIn, pathOut, fps)
 
if __name__=="__main__":
    main()
# Out:
# ./nst_wall/nst_001.jpg
# ./nst_wall/nst_002.png
# ./nst_wall/nst_003.png
# ./nst_wall/nst_004.png
# ./nst_wall/nst_005.png
# ./nst_wall/nst_006.png
# ./nst_wall/nst_007.png
# ./nst_wall/nst_008.png
# ./nst_wall/nst_009.png
# ./nst_wall/nst_010.png
# ./nst_wall/nst_011.png
# ./nst_wall/nst_012.png
# ./nst_wall/nst_013.png
# ./nst_wall/nst_014.png
# ./nst_wall/nst_015.png
# ./nst_wall/nst_016.png
# ./nst_wall/nst_017.png
# ./nst_wall/nst_018.png
# ./nst_wall/nst_019.png
# ./nst_wall/nst_020.png
# ./nst_wall/nst_021.png
# ./nst_wall/nst_022.png
# ./nst_wall/nst_023.png
# ./nst_wall/nst_024.png
# ./nst_wall/nst_025.png
# ./nst_wall/nst_026.png
# ./nst_wall/nst_027.png
# ./nst_wall/nst_028.png
# ./nst_wall/nst_029.png
# ./nst_wall/nst_030.png
# ./nst_wall/nst_031.png
# ./nst_wall/nst_032.png
# ./nst_wall/nst_033.png
# ./nst_wall/nst_034.png
# ./nst_wall/nst_035.png
# ./nst_wall/nst_036.png
# ./nst_wall/nst_037.png
# ./nst_wall/nst_038.png
# ./nst_wall/nst_039.png
# ./nst_wall/nst_040.png
# ./nst_wall/nst_041.png
# ./nst_wall/nst_042.png
# ./nst_wall/nst_043.png
# ./nst_wall/nst_044.png
# ./nst_wall/nst_045.png
# ./nst_wall/nst_046.png
# ./nst_wall/nst_047.png
# ./nst_wall/nst_048.png
# ./nst_wall/nst_049.png
# ./nst_wall/nst_050.png
# ./nst_wall/nst_051.png
# ./nst_wall/nst_052.png
# ./nst_wall/nst_053.png
# ./nst_wall/nst_054.png
# ./nst_wall/nst_055.png
# ./nst_wall/nst_056.png
# ./nst_wall/nst_057.png
# ./nst_wall/nst_058.png
# ./nst_wall/nst_059.png
# ./nst_wall/nst_060.png
# ./nst_wall/nst_061.png
# ./nst_wall/nst_062.png
# ./nst_wall/nst_063.png
# ./nst_wall/nst_064.png
# ./nst_wall/nst_065.png
# ./nst_wall/nst_066.png
# ./nst_wall/nst_067.png
# ./nst_wall/nst_068.png
# ./nst_wall/nst_069.png
# ./nst_wall/nst_070.png
# ./nst_wall/nst_071.png
# ./nst_wall/nst_072.png
# ./nst_wall/nst_073.png
# ./nst_wall/nst_074.png
# ./nst_wall/nst_075.png
# ./nst_wall/nst_076.png
# ./nst_wall/nst_077.png
# ./nst_wall/nst_078.png
# ./nst_wall/nst_079.png
# ./nst_wall/nst_080.png
# ./nst_wall/nst_081.png
# ./nst_wall/nst_082.png
# ./nst_wall/nst_083.png
# ./nst_wall/nst_084.png
# ./nst_wall/nst_085.png
# ./nst_wall/nst_086.png
# ./nst_wall/nst_087.png
# ./nst_wall/nst_088.png
# ./nst_wall/nst_089.png
# ./nst_wall/nst_090.png
# ./nst_wall/nst_091.png
# ./nst_wall/nst_092.png
# ./nst_wall/nst_093.png
# ./nst_wall/nst_094.png
# ./nst_wall/nst_095.png
# ./nst_wall/nst_096.png
# ./nst_wall/nst_097.png
# ./nst_wall/nst_098.png
# ./nst_wall/nst_099.png
# ./nst_wall/nst_100.png
# ./nst_wall/nst_101.png
