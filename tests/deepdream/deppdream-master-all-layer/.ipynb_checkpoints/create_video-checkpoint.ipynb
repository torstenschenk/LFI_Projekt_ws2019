# %%
import cv2
import numpy as np
import os
 
from os.path import isfile, join
 
def convert_frames_to_video(pathIn,pathOut,fps):
    frame_array = []
    files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]
 
    #for sorting the file names properly
    files.sort() #key = lambda x: int(x[5:-4]))
 
    for i in range(len(files)):
        filename=pathIn + files[i]
        #reading each files
        img = cv2.imread(filename)
        height, width, layers = img.shape
        size = (width,height)
        print(filename)
        #inserting the frames into an image array
        frame_array.append(img)
 
    out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
 
    for i in range(len(frame_array)):
        # writing to a image array
        
        cv2.putText(frame_array[i],files[i],(20,20), cv2.FONT_HERSHEY_SIMPLEX, 1.0,(255,255,0),1) 
        out.write(frame_array[i])
    out.release()
 
def main():
    pathIn= './frames_tree_set_layers/'
    pathOut = 'video.avi'
    fps = 2.0
    convert_frames_to_video(pathIn, pathOut, fps)
 
if __name__=="__main__":
    main()
# Out:
# ./frames_tree_set_layers/0000_conv0_start.jpg
# ./frames_tree_set_layers/0000_conv1_7x7_s2.jpg
# ./frames_tree_set_layers/0001_pool1_3x3_s2.jpg
# ./frames_tree_set_layers/0002_pool1_norm1.jpg
# ./frames_tree_set_layers/0003_conv2_3x3_reduce.jpg
# ./frames_tree_set_layers/0004_conv2_3x3.jpg
# ./frames_tree_set_layers/0005_conv2_norm2.jpg
# ./frames_tree_set_layers/0006_pool2_3x3_s2.jpg
# ./frames_tree_set_layers/0011_inception_3a_1x1.jpg
# ./frames_tree_set_layers/0012_inception_3a_3x3_reduce.jpg
# ./frames_tree_set_layers/0013_inception_3a_3x3.jpg
# ./frames_tree_set_layers/0014_inception_3a_5x5_reduce.jpg
# ./frames_tree_set_layers/0015_inception_3a_5x5.jpg
# ./frames_tree_set_layers/0016_inception_3a_pool.jpg
# ./frames_tree_set_layers/0017_inception_3a_pool_proj.jpg
# ./frames_tree_set_layers/0018_inception_3a_output.jpg
# ./frames_tree_set_layers/0023_inception_3b_1x1.jpg
# ./frames_tree_set_layers/0024_inception_3b_3x3_reduce.jpg
# ./frames_tree_set_layers/0025_inception_3b_3x3.jpg
# ./frames_tree_set_layers/0026_inception_3b_5x5_reduce.jpg
# ./frames_tree_set_layers/0027_inception_3b_5x5.jpg
# ./frames_tree_set_layers/0028_inception_3b_pool.jpg
# ./frames_tree_set_layers/0029_inception_3b_pool_proj.jpg
# ./frames_tree_set_layers/0030_inception_3b_output.jpg
# ./frames_tree_set_layers/0031_pool3_3x3_s2.jpg
# ./frames_tree_set_layers/0036_inception_4a_1x1.jpg
# ./frames_tree_set_layers/0037_inception_4a_3x3_reduce.jpg
# ./frames_tree_set_layers/0038_inception_4a_3x3.jpg
# ./frames_tree_set_layers/0039_inception_4a_5x5_reduce.jpg
# ./frames_tree_set_layers/0040_inception_4a_5x5.jpg
# ./frames_tree_set_layers/0041_inception_4a_pool.jpg
# ./frames_tree_set_layers/0042_inception_4a_pool_proj.jpg
# ./frames_tree_set_layers/0043_inception_4a_output.jpg
# ./frames_tree_set_layers/0048_inception_4b_1x1.jpg
# ./frames_tree_set_layers/0049_inception_4b_3x3_reduce.jpg
# ./frames_tree_set_layers/0050_inception_4b_3x3.jpg
# ./frames_tree_set_layers/0051_inception_4b_5x5_reduce.jpg
# ./frames_tree_set_layers/0052_inception_4b_5x5.jpg
# ./frames_tree_set_layers/0053_inception_4b_pool.jpg
# ./frames_tree_set_layers/0054_inception_4b_pool_proj.jpg
# ./frames_tree_set_layers/0055_inception_4b_output.jpg
# ./frames_tree_set_layers/0060_inception_4c_1x1.jpg
# ./frames_tree_set_layers/0061_inception_4c_3x3_reduce.jpg
# ./frames_tree_set_layers/0062_inception_4c_3x3.jpg
# ./frames_tree_set_layers/0063_inception_4c_5x5_reduce.jpg
# ./frames_tree_set_layers/0064_inception_4c_5x5.jpg
# ./frames_tree_set_layers/0065_inception_4c_pool.jpg
# ./frames_tree_set_layers/0066_inception_4c_pool_proj.jpg
# ./frames_tree_set_layers/0067_inception_4c_output.jpg
# ./frames_tree_set_layers/0072_inception_4d_1x1.jpg
# ./frames_tree_set_layers/0073_inception_4d_3x3_reduce.jpg
# ./frames_tree_set_layers/0074_inception_4d_3x3.jpg
# ./frames_tree_set_layers/0075_inception_4d_5x5_reduce.jpg
# ./frames_tree_set_layers/0076_inception_4d_5x5.jpg
# ./frames_tree_set_layers/0077_inception_4d_pool.jpg
# ./frames_tree_set_layers/0078_inception_4d_pool_proj.jpg
# ./frames_tree_set_layers/0079_inception_4d_output.jpg
# ./frames_tree_set_layers/0084_inception_4e_1x1.jpg
# ./frames_tree_set_layers/0085_inception_4e_3x3_reduce.jpg
# ./frames_tree_set_layers/0086_inception_4e_3x3.jpg
# ./frames_tree_set_layers/0087_inception_4e_5x5_reduce.jpg
# ./frames_tree_set_layers/0088_inception_4e_5x5.jpg
# ./frames_tree_set_layers/0089_inception_4e_pool.jpg
# ./frames_tree_set_layers/0090_inception_4e_pool_proj.jpg
# ./frames_tree_set_layers/0091_inception_4e_output.jpg
# ./frames_tree_set_layers/0092_pool4_3x3_s2.jpg
# ./frames_tree_set_layers/0097_inception_5a_1x1.jpg
# ./frames_tree_set_layers/0098_inception_5a_3x3_reduce.jpg
# ./frames_tree_set_layers/0099_inception_5a_3x3.jpg
# ./frames_tree_set_layers/0100_inception_5a_5x5_reduce.jpg
# ./frames_tree_set_layers/0101_inception_5a_5x5.jpg
# ./frames_tree_set_layers/0102_inception_5a_pool.jpg
# ./frames_tree_set_layers/0103_inception_5a_pool_proj.jpg
# ./frames_tree_set_layers/0104_inception_5a_output.jpg
# ./frames_tree_set_layers/0109_inception_5b_1x1.jpg
# ./frames_tree_set_layers/0110_inception_5b_3x3_reduce.jpg
# ./frames_tree_set_layers/0111_inception_5b_3x3.jpg
# ./frames_tree_set_layers/0112_inception_5b_5x5_reduce.jpg
# ./frames_tree_set_layers/0113_inception_5b_5x5.jpg
# ./frames_tree_set_layers/0114_inception_5b_pool.jpg
# ./frames_tree_set_layers/0115_inception_5b_pool_proj.jpg
# ./frames_tree_set_layers/0116_inception_5b_output.jpg
